# %% [markdown]
# <a href="https://colab.research.google.com/github/umashankar43631/colab_notebooks/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# Series - individual column /feature (just like we have in sql table)
# DataFrame - This has the format of table, each feature/column is a individual Series

# %%
se1 = pd.Series(np.arange(12,20))

# %%
se1
# Out:
# 0    12
# 1    13
# 2    14
# 3    15
# 4    16
# 5    17
# 6    18
# 7    19
# dtype: int64

# %%
se1.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
se2 = pd.Series(np.arange(20,30), index=['a','b','c','d','e','f','g','h','i','j'])

# %%
se2['a']
# Out:
# np.int64(20)

# %%
se2['a':'d'].dtype
# Out:
# dtype('int64')

# %%
se1.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
se2.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')

# %%
se2[se2>25]
# Out:
# g    26
# h    27
# i    28
# j    29
# dtype: int64

# %%
se2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-25-2866491713.py in <cell line: 0>()
# ----> 1 se2.columns
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
d1 = {'a':10,'b':20,'c':30,'d':40}

se3 = pd.Series(d1, name='values')

# %%
se3
# Out:
# a    10
# b    20
# c    30
# d    40
# Name: values, dtype: int64

# %%
se3.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
se3.index = ['maths', 'science', 'physics', 'Chemistry']

# %%
se3
# Out:
# maths        10
# science      20
# physics      30
# Chemistry    40
# Name: values, dtype: int64

# %%
d1 = {"state": ['Andhra Pradesh', 'Jaipur', 'Telangana'],
      "gdp": [6000,7000, 8000],
      "population": [10000, 20000,40000]}

# %%
df1 = pd.DataFrame(d1)

# %%
df1
# Out:
#             state   gdp  population
# 0  Andhra Pradesh  6000       10000
# 1          Jaipur  7000       20000
# 2       Telangana  8000       40000

# %%
df2 = pd.DataFrame(d1, columns=['state', 'gdp'])
df2
# Out:
#             state   gdp
# 0  Andhra Pradesh  6000
# 1          Jaipur  7000
# 2       Telangana  8000

# %%
d2 = {"state": ['Andhra Pradesh', 'Jaipur', 'Telangana', 'st4', 'st5', 'st6','st7'],
      "gdp": np.arange(100,800,100),
      "population": np.arange(10000,80000,10000)}

# %%
df3 = pd.DataFrame(d2)

# %%
df3
# Out:
#             state  gdp  population
# 0  Andhra Pradesh  100       10000
# 1          Jaipur  200       20000
# 2       Telangana  300       30000
# 3             st4  400       40000
# 4             st5  500       50000
# 5             st6  600       60000
# 6             st7  700       70000

# %%
df3.head() # top 5 rows, we can mention no of rows we need by specifying value inside it.
# Out:
#             state  gdp  population
# 0  Andhra Pradesh  100       10000
# 1          Jaipur  200       20000
# 2       Telangana  300       30000
# 3             st4  400       40000
# 4             st5  500       50000

# %%
df3.tail()
# Out:
#        state  gdp  population
# 2  Telangana  300       30000
# 3        st4  400       40000
# 4        st5  500       50000
# 5        st6  600       60000
# 6        st7  700       70000

# %%
df3.shape
# Out:
# (7, 3)

# %%
df3['state'].unique()
# Out:
# array(['Andhra Pradesh', 'Jaipur', 'Telangana', 'st4', 'st5', 'st6',
#        'st7'], dtype=object)

# %%
df3['gdp'].sum()
# Out:
# np.int64(2800)

# %%
import seaborn as sns

tips = sns.load_dataset('tips')
# tips = pd.read_csv("tips.csv")

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips = pd.read_csv("tips.csv")
